# %%
import numpy as np

# %% [markdown]
# ## DataTypes & Attributes

# %%
# Numpy's main datatype is ndarray
a1=np.array([1,2,3])
a1
# Out:
# array([1, 2, 3])

# %%
 sample_array=np.array([1,2,3])
sample_array
# Out:
# array([1, 2, 3])

# %%
sample_array.dtype
# Out:
# dtype('int32')

# %%
ones=np.ones((2,3))

# %%
range_array=np.arange(0,10,2)
range_array
# Out:
# array([0, 2, 4, 6, 8])

# %%
random_array=np.random.random((1,9))
random_array
# Out:
# array([[0.77538723, 0.01345484, 0.88686572, 0.50110221, 0.72002251,
#         0.15921137, 0.41746493, 0.9317901 , 0.6568934 ]])

# %%
random_array2=np.random.rand(5,3)
random_array2
# Out:
# array([[0.67060625, 0.56880329, 0.77161186],
#        [0.45884204, 0.55442593, 0.13654175],
#        [0.54466516, 0.39297327, 0.54664076],
#        [0.71238002, 0.83396576, 0.03141181],
#        [0.29147923, 0.25358463, 0.30043958]])

# %%
# Pseudo-random numbers
#np.random.seed()

# %%
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 import matplotlib.pyplot as plt
#       2 import pandas as pd
# ----> 3 lkml
#
# NameError: name 'lkml' is not defined

# %%
plt.plot([1,2,3,4])

# %%
x=[1,2,3,4]
y=[11,22,33,44]
plt.plot(x,y)

# %%
plt.plot(data)

# %%
# 1 St method
fig=plt.figure()
ax=fig.add_subplot()
plt.show()

# %%
# 2SD METHOD
fig=plt.figure()
ax=fig.add_axes([1,1,1,1])
ax.plot(x,y)

# %%
x=[1,2,3,4]
y=[11,22,33,44]

# 2. Setup Plot
fig,ax=plt.subplots(figsize=(10,10))

#plot data
ax.plot(x,y)

# 4 Customize plot
ax.set(title="Simple plot", xlabel="x-axis", ylabel="y-axis")
# Out:
# [Text(0.5, 1.0, 'Simple plot'), Text(0.5, 0, 'x-axis'), Text(0, 0.5, 'y-axis')]

# %%
import numpy as np

# %%
# Create some data
x=np.linspace(0,10,999999)
# Out:
# array([0.000000e+00, 1.000002e-05, 2.000004e-05, ..., 9.999980e+00,
#        9.999990e+00, 1.000000e+01])

# %%
# plot the data
fig,ax=plt.subplots()
ax.plot(x,x**2)

# %%
# Use same data to make a scatter
fig,ax=plt.subplots()
ax.scatter(x,np.sin(x))

# %%
# Make a plot from dictionnary
nut_butter_prices={"Almost butter":10, "Peanut Butter":8, "Cashow Butter":12}
fig, ax=plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title="Dans Nut Butter Store")
# Out:
# [Text(0.5, 1.0, 'Dans Nut Butter Store')]
